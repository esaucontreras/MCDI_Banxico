# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Inteligencia-Artificial-en-Economía:-Clasificación-de-Reportes-de-Banxico-mediante-LLMs-y-Análisis-de-Tópicos-(LDA)" data-toc-modified-id="Inteligencia-Artificial-en-Economía:-Clasificación-de-Reportes-de-Banxico-mediante-LLMs-y-Análisis-de-Tópicos-(LDA)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><strong>Inteligencia Artificial en Economía: Clasificación de Reportes de Banxico mediante LLMs y Análisis de Tópicos (LDA)</strong></a></span></li></ul></div>

# %% [markdown]
# # **Inteligencia Artificial en Economía: Clasificación de Reportes de Banxico mediante LLMs y Análisis de Tópicos (LDA)**
#
#
# **Benjamín Esaú Contreras Solis**
#
# Maestría en Ciencia de Datos e Información (MCDI)
# INFOTEC

# %%
#pip install deep-translator
#%pip install --user --upgrade openai

# %%
import requests
import openai as OpenAI
import pandas as pd
import unicodedata
from collections import Counter
import matplotlib.pyplot as plt
import itertools
from itertools import combinations
import numpy as np
import json
import pandas as pd
import time as tm
#from deep_translator import GoogleTranslator

# %% [raw]
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %%time
url = "https://www.dropbox.com/scl/fi/n2tsmswnk4ymm3zz0wteg/CBS_dataset_v1.0.csv?rlkey=sdxk6b9xpid0xe7w7s4nm6s87&dl=1"

# leer
r = requests.get(url)
open('CBS_dataset.csv', 'wb').write(r.content)

#
df = pd.read_csv("CBS_dataset.csv", usecols=["text"] , nrows=9001)#, skiprows = range(0,21327))
# para solo leer columna en inglés
df = df['text']
df.head()
# Out:
# Wall time: 2min 45s
# 0    Managing the Economy as if the Future Really M...
# 1    Safeguarding our Future: Strategies for an Aru...
# 2    FOSTERING ECONOMIC RESILIENCE IN ARUBA; FROM R...
# 3    Presentation by Mrs Jeanette R. Semeleer, Pres...
# 4    Ongoing changes in the supervisory landscape a...
# Name: text, dtype: object

# %%
prompt = """
Eres un analista económico especializado en bancos centrales y con nivel avanzado de inglés. Traduce a español cada texto que te voy a compartir.




**REGLAS ESTRICTAS**:
1. **NO** agregues resúmenes, explicaciones, ni texto fuera del formato.
2. **NO** inventes información.
3. **SI** incumples las reglas, la respuesta será incorrecta.
4. **NO* agregues notas ni explicaciones
5.  **NO** quiero otra cosa diferente de ese formato
6. **NO** me des más información más que la traducción.

"""

# %%
# %%javascript
# function ClickConnect(){
#   console.log("Evitar desconexión de Google Colab");
#   document.querySelector("colab-toolbar-button#connect").click();
# }
# setInterval(ClickConnect, 60000); // cada 60 segundos

# %%
df[7410][0:120]
# Out:
# '19/09/22, 16:52 Hong Kong Monetary Authority - The Development of Financial Centres - Policy and Prudential Issues Speec'

# %%
#df  = df[0:10002]
len(df)
# Out:
# 9001

# %%
# %%time
from openai import OpenAI
lista_es = []
#OUTPUT_FILE = "/content/drive/MyDrive/traducciones_30001_35000.txt"


pp = 7500
qq =9001

OUTPUT_FILE = "traducciones_"+str(pp)+"_"+str(qq)+".txt"
# Crear archivo si no existe
open(OUTPUT_FILE, "a").close()

client = OpenAI(
    api_key="sk-ae84c58c6e124bd5836377722031e1a3",
    base_url="https://api.deepseek.com/v1"
)

for i in range(pp,qq):

    print("Lista " + str(i) + "/" + str(qq))

    texto = str(df[i])
    entrada = prompt + texto

    response = client.chat.completions.create(
        model="deepseek-chat",
        messages=[{"role": "user", "content": entrada}]
        #,
         #   timeout=30  
    )

    traduccion = response.choices[0].message.content
    #lista_es.append(traduccion)

    # ➜ GUARDAR DE INMEDIATO EN .TXT
    with open(OUTPUT_FILE, "a", encoding="utf-8") as f:
        f.write(str(i+1) + " " + traduccion.replace('\n', ' ') + "\n")

    # Pausa para no saturar la API
    if (i + 1) % 100 == 0:
        print(f"{i+1} completados - Pausa de 2s...")
        tm.sleep(2)
# Out:
# Lista 7500/9001
# Lista 7501/9001
# Lista 7502/9001
# Lista 7503/9001
# Lista 7504/9001
# Lista 7505/9001
# Lista 7506/9001
# Lista 7507/9001
# Lista 7508/9001
# Lista 7509/9001
# Lista 7510/9001
# Lista 7511/9001
# Lista 7512/9001
# Lista 7513/9001
# Lista 7514/9001
# Lista 7515/9001
# Lista 7516/9001
# Lista 7517/9001
# Lista 7518/9001
# Lista 7519/9001
# Lista 7520/9001
# Lista 7521/9001
# Lista 7522/9001
# Lista 7523/9001
# Lista 7524/9001
# Lista 7525/9001
# Lista 7526/9001
# Lista 7527/9001
# Lista 7528/9001
# Lista 7529/9001
# Lista 7530/9001
# Lista 7531/9001
# Lista 7532/9001
# Lista 7533/9001
# Lista 7534/9001
# Lista 7535/9001
# Lista 7536/9001
# Lista 7537/9001
# Lista 7538/9001
# Lista 7539/9001
# Lista 7540/9001
# Lista 7541/9001
# Lista 7542/9001
# Lista 7543/9001
# Lista 7544/9001
# Lista 7545/9001
# Lista 7546/9001
# Lista 7547/9001
# Lista 7548/9001
# Lista 7549/9001
# Lista 7550/9001
# Lista 7551/9001
# Lista 7552/9001
# Lista 7553/9001
# Lista 7554/9001
# ...

# %% [raw]
# %%time
#
# #CHINA
# from openai import OpenAI
# lista_es = []
# #OUTPUT_FILE = "/content/drive/MyDrive/traducciones_30001_35000.txt"
# OUTPUT_FILE = "traducciones_01822_1890.txt"
#
# # Crear archivo si no existe
# open(OUTPUT_FILE, "a").close()
#
# #client = OpenAI(
#  #   api_key="sk-ae84c58c6e124bd5836377722031e1a3",
#   #  base_url="https://api.deepseek.com/v1"
# #)
#
# for i in range(1822,1890):
#
#     print("Lista " + str(i) + "/" + str(len(df)))
#
#     texto = str("Sin Traducción China")
#     #entrada = prompt + texto
#
#     #response = client.chat.completions.create(
#      #   model="deepseek-chat",
#       #  messages=[{"role": "user", "content": entrada}]
#         #,
#          #   timeout=30
#     #)
#
#     #traduccion = response.choices[0].message.content
#     lista_es.append(texto)
#
#     # ➜ GUARDAR DE INMEDIATO EN .TXT
#     with open(OUTPUT_FILE, "a", encoding="utf-8") as f:
#         f.write(str(i+1) + " " + texto.replace('\n', ' ') + "\n")
#
#     # Pausa para no saturar la API
#     if (i + 1) % 100 == 0:
#         print(f"{i+1} completados - Pausa de 2s...")
#         tm.sleep(2)

# %% [raw]
# Home News & Events Speeches Transcript of Group Interview with Pan Gongsheng, Spokesperson for the Central Financial System Delegation to the 20th CPC National Congress a To Read Chinese Version On October 20, the press center for the 20th National Congress of the Communist Party of China (CPC) hosted a group interview with the spokespersons for the delegations from Qinghai, Ningxia, Xinjiang, the central Party and government departments, the central financial system, and the centrally administered state-owned enterprises (in Beijing). Speaking on behalf of the delegation from the central financial system, Pan Gongsheng, member of the CPC PBC Committee and deputy governor of the Peoples Bank of China (PBC), also secretary of the CPC Leadership Group of the State Administration of Foreign Exchange (SAFE) and SAFE administrator, introduced the delegations study of the report to the 20th CPC National Congress and answered questions from journalists. The transcript is as follows. Moderator: Now Id like to give the floor to Comrade Pan Gongsheng from the central financial system delegation. Pan Gongsheng: Good evening, everyone. There have always been good interactions between the media and the financial system. Today, on behalf of the central financial system delegation and
financial system do to implement these requirements? What will be the focus of financial work in the upcoming period? Thank you. Pan Gongsheng: The financial system takes it as an important political task to thoroughly implement the spirit of the report to the 20th CPC National Congress. We will follow the guidance of the report. From macro and strategic perspectives, we will focus our work on the following. First, we will uphold the centralized, unified leadership of the CPC Central Committee over financial work. We will stress the Partys leadership throughout the process and in every respect of financial work. We will implement resolutely and efficiently the major decisions and arrangements of the CPC Central Committee. Furthermore, we will continue to improve the systems and mechanisms for the exercise of the Partys leadership over financial work so as to turn the institutional advantages, as shown by the Partys leadership, into financial governance capacity. Second, we will stay committed to providing financial support for the real economy. We will pursue a sound monetary policy, strengthen cross-cycle and countercyclical adjustments, and create a monetary and financial environment conducive to boosting economic growth, expanding employment, stabilizing prices and maintaining the balance of payments. We will guide financial resources to better support the key fields and weak links in economic and social development, and offer high-quality financial services to promote high-quality development of the Chinese economy. Third, we will always coordinate development and security and firmly defend the bottom line whereby no systemic financial risk will occur. Forestalling and defusing financial risks is an eternal theme for the financial sector. The financial system will give higher priority to the prevention and control of financial risks and will improve the mechanisms for risk prevention, early warning and resolution to safeguard Chinas financial stability and financial security. Fourth, we will continue to deepen financial reform and opening-up. We will push further ahead with the supply-side structural reform of the financial sector, put efforts into developing inclusive finance, green finance, sci-tech finance and digital finance, and promote the sound and stable development of a multi-tiered capital market. We will deepen the market-oriented exchange rate reform and keep the RMB exchange rate basically stable at an adaptive and equilibrium level. In addition, we will promote the high-quality two-way opening-up of the financial sector and actively participate in international financial governance. We will enhance financial regulatory capacity and strengthen the financial legal system. Fifth, we will continue to strengthen Party self-governance in every respect and conduct high- quality Party building to promote high-quality financial development. We will carry on the building of a team of financial professionals who are loyal and upright and have a strong sense of responsibility. We will severely punish corruption in the financial field and ensure that financial work adheres to its political character and serves the interests of the people. We firmly believe that under the strong leadership of the CPC Central Committee with Comrade Xi Jinping at its core, we will take solid steps forward on the path of financial development with Chinese characteristics and provide strong financial support for the pursuit of the Chinese path to modernization. Thank you. Date of last update OCT. 21,2022
#
#
# Lista 1821/5001
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\AppData\Roaming\Python\Python39\site-packages\openai\_utils\_utils.py in wrapper(*args, **kwargs)
#     284                         msg = f"Missing required argument: {quote(missing[0])}"
#     285                 raise TypeError(msg)
# --> 286             return func(*args, **kwargs)
#     287
#     288         return wrapper  # type: ignore
#
# ~\AppData\Roaming\Python\Python39\site-packages\openai\resources\chat\completions\completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1190     ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1191         validate_response_format(response_format)
# -> 1192         return self._post(
#    1193             "/chat/completions",
#    1194             body=maybe_transform(
#
# ~\AppData\Roaming\Python\Python39\site-packages\openai\_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1257             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258         )
# -> 1259         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1260
#    1261     def patch(
#
# ~\AppData\Roaming\Python\Python39\site-packages\openai\_base_client.py in request(self, cast_to, options, stream, stream_cls)
#    1045
#    1046                 log.debug("Re-raising status error")
# -> 1047                 raise self._make_status_error_from_response(err.response) from None
#    1048
#    1049             break
#
# BadRequestError: Error code: 400 - {'error': {'message': 'Content Exists Risk', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}
